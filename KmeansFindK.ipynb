# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Following were results from Cross validation for different K values for K-means <br />
#         WCSS for K=2 is 1993.2469974371381 <br />
#         WCSS for K=3 is 1947.105690213165 <br />
#         WCSS for K=5 is 1888.1340219025037 <br />
#         WCSS for K=10 is 1818.4268052367956 <br />
#         WCSS for K=20 is 1758.8531074740106 <br />

# %%
K_values = [2,3,5,10,20]
WCSS_values = [1993.25, 1947.11, 1888.13, 1818.43, 1758.85]

# %%
plt.plot(K_values, WCSS_values)
plt.plot([10],[1818.43],'ro')
plt.title('Determing suitable K for K-means')
plt.xlabel('K')
plt.ylabel('WCSS')
plt.show()
